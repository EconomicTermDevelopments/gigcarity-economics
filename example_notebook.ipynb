# %% [markdown]
# # Gigcarity\n\nPhase 2 notebook walkthrough.

# %%
import pandas as pd\nfrom gigcarity import GigcarityCalculator\n

# %%
df = pd.read_csv("gigcarity_dataset.csv")\ndf.head()\n

# %%
calc = GigcarityCalculator()\nresult = calc.calculate_gigcarity(df)\nresult.head()\n

# %%
result["gigcarity_index"].describe()\n

# %%
result.groupby("gigcarity_band").size()\n

# %%
result["gigcarity_index"].hist(bins=20)\n

# %% [markdown]
# Interpretation: `Gigcarity` index is now ready for stress testing.
